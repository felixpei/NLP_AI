# %% [markdown]
# # text's feature engineering: turn unstructure to  structure

# %%
import re
import pandas as pd
import numpy as np
import pickle
import os

## turn back to main directory
#os.chdir("./NLP/AIA")
os.getcwd()
# Out:
# '/Users/felix/Archive/TechSite/AI/AIA_技術班/PyEx/NLP/AIA'

# %%
df = pd.read_csv('data/article_preprocessed.csv')

# %%
df
# Out:
#                         id                        title  \
# 0       M.1502380736.A.AC4           [問卦] 韓瑜 跟 周子瑜 怎麼選?
# 1       M.1502380714.A.3B4       [問卦] 逢甲碟仙說兩岸統一到底是真是假！？
# 2       M.1502380707.A.6A6                  [問卦] 風雲起山河動
# 3       M.1502380681.A.18F               [問卦] 男朋友不睡覺怎麼辦
# 4       M.1502380627.A.383         [問卦] 英雄聯盟是不是已經漸漸過氣了?
# 5       M.1502380209.A.CBA            [問卦] 覺得每天都睡不飽會怎樣？
# 6       M.1502380394.A.318           [問卦] messenger的新功能
# 7       M.1502380316.A.A9E           [問卦] 趁深夜去山路綁鋼絲會如何？
# 8       M.1502380294.A.095                  [爆卦] 味全7月營收
# 9       M.1502380292.A.396   [問卦] 金城武知道這是8月10號唯一篇金城武文嗎?
# 10      M.1502380291.A.40B            [問卦] 台大機械跟清大電資哪個好
# 11      M.1502380263.A.1CA               [問卦] 有無鍛刀大賽的掛？
# 12      M.1502380603.A.C7F            [問卦] 南一中跟板橋高中哪個好?
# 13      M.1502380598.A.2BA         [問卦] 為何頂尖圖書館都是蘋果筆電呢?
# 14      M.1502380587.A.E98              [問卦] 有沒有當機師的八卦?
# 15      M.1502380574.A.F58             [問卦] 大家出遊會保旅平險嗎?
# 16      M.1502380479.A.749           [問卦] ☺☺☺對著月亮打手槍☺☺☺
# 17      M.1502379795.A.4E7               [問卦] 爭鮮為啥不開24小
# 18      M.1502380013.A.B28         [問卦] 哪些大學使用BT抓片會被抓呢?
# 19      M.1502379919.A.573             [問卦] 學會六式起薪大概多少?
# 20      M.1502379910.A.E80            [問卦] 為什麼大人愛吃小嬰兒屁股
# 21      M.1502379865.A.DB6          [問卦] 寫字美的男生把妹還有優勢嗎？
# 22      M.1502379846.A.40F        [問卦] 問哪部的人是真的想知道哪部嗎??
# 23      M.1502379841.A.9C1          [問卦] 有沒有木柵附近怎麼了的八卦？
# 24      M.1502379796.A.85E             [問卦] 我女朋友想去懶覺博物館
# 25      M.1502380119.A.931     [問卦] 北韓說飛彈會飛過日本上空,日本會做什麼
# 26      M.1502380061.A.096             [問卦] 到台北唸書比較厲害嗎？
# 27      M.1502380051.A.F0E            [問卦] 什麼系才是糞系中的霸主？
# 28      M.1502379253.A.C4A               [問卦] 哪家航空空姐最正？
# 29      M.1502379514.A.5E9            [問卦] 有沒有新訓掉筷子的八卦？
# ...                    ...                          ...
# 252199  M.1505405862.A.C95            [問卦] 西門要吃什麼才有指標性?
# 252200  M.1505405852.A.ACE        [問卦] 進八卦板板主決選484很值得炫耀
# 252201  M.1505405320.A.0EC            [問卦] 有沒有半島鐵盒很難唱的卦
# 252202  M.1505405577.A.310            [問卦] 只有南部人喜歡吃正忠嗎？
# 252203  M.1505405541.A.47E          [問卦] 宅男要怎樣才不會被發好人卡?
# 252204  M.1505405524.A.815             [問卦] 有沒有半島鐵盒的八卦?
# 252205  M.1505405442.A.171           [問卦] 正妹敢跟肥宅簽愛情契約嗎？
# 252206  M.1505405401.A.3C4  [問卦] 性慾高漲--->禿頭 雞軟--->禿頭???
# 252207  M.1505405345.A.CAE              [問卦] 女用機是不是比較好呢
# 252208  M.1505405684.A.060               [問卦] 有沒有柯柯麗的八卦
# 252209  M.1505405606.A.300        [問卦] 買豬絞肉，不要的肥豬油要算錢嗎?
# 252210  M.1505405578.A.9E1              [問卦] 北藝大什麼時候這麼強
# 252211  M.1505404996.A.A1C              [問卦] 水漾青春會出藍光嗎？
# 252212  M.1505405202.A.62C                  [問卦] 漢來吃回本?
# 252213  M.1505405163.A.7B7          [問卦] 如果拔智齒到一半麻藥退會怎樣
# 252214  M.1505405161.A.1E8            [問卦] 有沒有 太極門 的八卦？
# 252215  M.1505405099.A.A82              [問卦] 有沒有身不由己的八卦
# 252216  M.1505405082.A.4DE     [問卦] 納智捷把車送去歐洲做撞擊測試 有加分嗎
# 252217  M.1505405067.A.C99             [問卦] 館長和龍五對打誰會贏?
# 252218  M.1505405057.A.AFD    [問卦] 宅宅多聽八嘎炯兄弟系的歌會增加氣概嗎??
# 252219  M.1505405051.A.B3D         [爆卦] 公司企業小心李彥廣大舉興訟告人
# 252220  M.1505405048.A.A78                   [問卦] 夏天買陰宅
# 252221  M.1505405025.A.2FC      [問卦] 有沒有按妙禪讚的朋友都比我厲害的卦?
# 252222  M.1505405305.A.938             [問卦] P幣為什麼這麼難賺啊？
# 252223  M.1505405215.A.5D7     [問卦] 有沒有台灣女藝人整天拿懷孕當梗的八卦？
# 252224  M.1505405210.A.C69       [問卦] 信徒能感覺到SEAFOOD的靈壓嗎
# 252225  M.1505404956.A.DDC  [問卦] 比較喜歡吃seafood還是skyfood?
# 252226  M.1505404929.A.7F0   [問卦] seafood幾千人的場合真的沒有一個臥底
# 252227  M.1505404909.A.4CF                [問卦] 有沒有蚰蜒的八卦
# 252228  M.1505404806.A.A2C            [問卦] 一到新部隊班長就在電人？
#
#                                                   content  \
# 0       韓瑜是協志的前妻 也是很正的女演員 周子瑜是TWICE團裡裡面的台灣人 也是很正 這兩個要當...
# 1       dear all 逢甲碟仙發生在民國七十五年三月中的事情， 一堆大學生玩碟仙然後發bbs 成...
# 2       晚上好啊 各位 預備唱 風雲起 山河動 為什麼國軍早上都要唱這個啊 有沒有相關的八卦？？ S...
# 3       明天要早起 可是他不睡覺 在旁邊看Youtube這樣眼睛會壞掉 有沒有方法可以讓他早點睡 掛...
# 4       一段時間沒在注意LOL了 結果發現各大LOL討論區人數有在明顯下降的趨勢 這實在令人滿驚訝的...
# 5       總覺得 每天都睡不飽 但是啊 到睡覺時間反而又睡不著 長時間這樣會怎樣啊？ 有沒有相關八卦？...
# 6       現在messenger好像有一個新功能 就是只要打到類似日期的文字 就會出現底線 再點選就可...
# 7          如題 一堆山路天黑後沒路燈暗冥矇 如果有人用一套很長的鋼絲 綁在山壁護欄 天亮後會怎樣呢？
# 8       本資料由 (上市公司) 味全公司 公司提供 民國106年07月 單位：新台幣仟元 項目 營業...
# 9       如題 這篇文是8月10號唯一一篇金城武文 如果沒有今天這篇的話 金城武文就會中斷連續一個多月...
# 10      看今年指考 台大機械幹掉清大電資學士跟清大資工資電組 而且台大機械收的人比較多 看板上資電這...
# 11      本來水管上有一搭沒一搭的有人放 現在都被操掉惹 第三季還沒看到一半啊 想請問有無鍛刀大賽的八...
# 12      南部高中分數好像越來越低了。 相反地，北部高中似乎分數越來越高。 請問南一中如果到北北基， ...
# 13      看到很多頂尖國立大學的圖書館， 裡面學生一望無際都使使用蘋果筆電居多。 蘋果筆電的價格不是都...
# 14      當機師聽說月薪一二十萬 然後跟別人說你是開飛機的 也很酷 但版上為啥都只推當醫師 工程師呢?...
# 15      最近出國，問到有的人從沒保的，他說刷卡就有送，就算搭機出事， 航空公司也會保的，保那幹麻，故...
# 16      嘻嘻嘻 肥肥們ㄤㄤ 我亞綸ㄌ:3 小時候聽說 用手指著月亮 耳朵會被割下來 那用雞雞指著月亮...
# 17      眾多肥宅單身好選擇的爭鮮 為什麼不開24小時 餵養眾多單身肥宅 是怕半夜整家店散發出宅味嘛?...
# 18      之前有傳出說有人使用大學宿網來下載BT被抓。 我想請問大家，現在教育部學術網路還有在抓BT嗎...
# 19      乳蹄 在水之七島的那個美好年代 六式是超越人體極限的超人技能 雖然後來鐵塊被武裝色壓制 紙繪...
# 20      之前看過幾個爸爸媽媽跟自己的小寶寶在玩 結果看到他們用嘴巴玩他屁股(應該不是吃) 會用一個ㄅ...
# 21      字美的男生除了國考申論題有點優勢， 實在想不出把妹有什麼優勢， 以前把妹是寫情書賣弄文采， ...
# 22      看到有多人推文留言都會問哪部 這樣問是嗆聲還是真的想知道 他們都把肥宅的發文當成某作品的影射...
# 23      剛剛本魯在河濱騎腳踏車 聽到了很多消防車的聲音好像往木柵焚化爐那邊去 有沒有發生了什麼事的八卦？
# 24      乳提 今天我可愛的女朋友在摸完我的雞雞後跟我說 好想去懶覺博物館參觀各種雞雞喔 可是我不知道...
# 25      北韓已經嗆聲，八月中會射四顆飛彈，彈著點在關島附近海域， 飛彈路徑會經過日本的本土。 試想，...
# 26      台北的學生可能不懂 但對我們中南部的學生來說 大學到台北唸書 就是一個字 邱 現在偶爾回家還...
# 27              乳題 大學科系千百種，好系帶你上天堂，糞系讓你進糞坑 究竟什麼系才是糞系中的霸主
# 28      本魯預計開學後一週要去日本玩，為啥要開學後一週是因為不想跟肥宅擠同班飛機， 臭味都臭死了， ...
# 29      八卦版的六星肥將安安，小肥我在新訓的時候，舉凡用餐時，一定都會有人掉筷子，班長 聽到掉筷聲好...
# ...                                                   ...
# 252199  跟新認識的洋妞約周六吃飯 在西門町 要吃什麼才能代表台灣 又讓人印象深刻呢 我是覺得什麼阿雜...
# 252200  如題 大家都知道 在批踢踢裡 八卦板幾乎都是第一大板 有超多人ＤＥＲ 如果參加八卦板板主的投...
# 252201  各位魯蛇 ecup大家好 每次乳肥宅我跟碰油去唱歌的時候 本魯的碰油都會點半島鐵盒來唱 幹 ...
# 252202  最近幾天上班， 到午餐時間，同事問吃什麼， 本魯提議 “正忠 炸雞腿飯 好吃 阿嘶” 立刻被...
# 252203  宅男這個族群很可憐 感情上常常不求回報當女生的工具人 搞不好還花大錢送禮物給女生 結果還是只...
# 252204  半島鐵盒是什麼東西呢 有人說是一種便當盒 有人說是音樂盒 有人說是盒盒 到底有沒有人知道半島...
# 252205  就是偶像劇還是少女漫畫常常看到的戀愛契約 什麼交往幾個月就要分開~~ 規定愛上對方就是違約~...
# 252206  大家好 讓八卦充滿溫暖你我有責 根據研究啦 性慾高漲> ggininder >禿頭 那雞軟又...
# 252207  是這樣的 最近在逛一些二手商品 結果發現很多賣家都會標榜自己賣的是女用機 價格就會比較硬 難...
# 252208  柯柯麗，職業是魔法師 黑暗族裔米古米古的最後遺裔，能使用咕嚕咕嚕魔法 記性差，常常畫出錯誤的...
# 252209  我挺好奇的， 肥豬油我又沒有買， 豬肉攤完全可以再賣給別人。 那為何要算錢呢? 有人可以合理...
# 252210  我朋友北藝大畢業 去當醫生 他之前去約旦河當戰地醫生 後來遇到爆炸案 剛回來台灣 北藝大什麼...
# 252211  今晚魯宅法師我突然想到 有部影片叫水漾青春 是在講性教育的 拍的超級微美害羞 連我看了都臉紅...
# 252212  去敦化南路吃過一次 比響食還貴 卻只有兩道菜是響食沒有的 1.雞尾調酒 2.南瓜子 想知道下...
# 252213  如題 上禮拜去拔智齒 拔完的感覺真是舒爽 可是在拔的時候超怕麻藥退的 有沒有拔的中途麻藥退會...
# 252214  太極門 揪竟是個怎樣的團體？ 北部各地好像有滿多據點der 是像seafood 一樣感恩讚歎...
# 252215  怕我的背影 把你吵醒 所以 轉身 帶走所有秘密 生命是一連串的 身不由己 愛就沒有非要完美的...
# 252216  不囉嗦 先上送去撞擊測試的兩台車影片  看完撞擊結果 車體剛性好像還可以欸 不過已經黑掉的納...
# 252217  館長跟龍五對打誰會贏? 館長 散打冠軍 龍五 有槍誰都無法殺他 大家覺得呢? 是否有專板 ，...
# 252218  最近有在看巴嘎炯直播 他們背景都會放一些兄弟系或情歌系的歌 都不是一般宅宅在聽得初音或大眾系...
# 252219  就在剛剛 跟其中一間公司的人員確認過了 這人只要離職 就會提告 先告確認僱傭關係存在 下一步...
# 252220  如題 請問一下 在夏天買陰宅 是不是省電的最佳解 不但整天都不需要開冷氣 而且運氣好的話 晚...
# 252221  安安 我對妙禪沒甚麼既定印象啦，就是個宗教團體，不拉我進去就感覺還好 只是最近看一下身邊朋友...
# 252222  本魯肥宅潛水許久，最近才發現p幣的好用之處。 為什麼Ptt沒有像現在的手遊一樣，每天登入 都...
# 252223  為什麼台灣女藝人 多半沒有好作品的那批女藝人 很喜歡不定時主動放出懷孕等假新聞 來衝人氣？或...
# 252224  看影片每個信徒一接近SEAFOOD還是雙手合十就哭得一把鼻涕一把眼淚的 讓小魯不禁想問 SE...
# 252225  諸位晚安 如題 不知道諸位比較喜歡吃seafood還是skyfood? 不才在下先拋磚引玉 ...
# 252226  utube上幾千人的場合 一起喊 感謝seafood 讚嘆seafood 一起跪拜 一起起乩...
# 252227            剛剛打死了連念都不會念的蚰蜒 有沒有他的八卦？ 我覺得他看起來比蟑螂好欺負說
# 252228  小魯早上在往新部隊的軍車上哼歌 就有個穿便服的白目一直看著我笑 到部隊後 一下車值星就叫我們...
#
#                             date  push  boo     idx
# 0       Thu Aug 10 23:58:53 2017     4    4       0
# 1       Thu Aug 10 23:58:30 2017    14    3       1
# 2       Thu Aug 10 23:58:22 2017    13    0       2
# 3       Thu Aug 10 23:57:58 2017     1    4       3
# 4       Thu Aug 10 23:57:04 2017    10    1       4
# 5       Thu Aug 10 23:50:03 2017     2    2       5
# 6       Thu Aug 10 23:53:11 2017     1    4       6
# 7       Thu Aug 10 23:51:53 2017     3    2       7
# 8       Thu Aug 10 23:51:31 2017    26   10       8
# 9       Thu Aug 10 23:51:28 2017     2    2       9
# 10      Thu Aug 10 23:51:28 2017    15    4      10
# 11      Thu Aug 10 23:51:00 2017     4    1      11
# 12      Thu Aug 10 23:56:40 2017    10    6      12
# 13      Thu Aug 10 23:56:35 2017     3    0      13
# 14      Thu Aug 10 23:56:24 2017     2    3      14
# 15      Thu Aug 10 23:55:51 2017    13    0      15
# 16      Thu Aug 10 23:54:35 2017     2    7      16
# 17      Thu Aug 10 23:43:12 2017     6    0      17
# 18      Thu Aug 10 23:46:50 2017     0    0      18
# 19      Thu Aug 10 23:45:15 2017     1    3      19
# 20      Thu Aug 10 23:45:07 2017     4    2      20
# 21      Thu Aug 10 23:44:22 2017    12    4      21
# 22      Thu Aug 10 23:44:03 2017     2    8      22
# 23      Thu Aug 10 23:43:59 2017     3    0      23
# 24      Thu Aug 10 23:43:10 2017     3    5      24
# 25      Thu Aug 10 23:48:36 2017     5    1      25
# 26      Thu Aug 10 23:47:38 2017     7    3      26
# 27      Thu Aug 10 23:47:28 2017    13    4      27
# 28      Thu Aug 10 23:34:10 2017    11    3      28
# 29      Thu Aug 10 23:38:32 2017     7    1      29
# ...                          ...   ...  ...     ...
# 252199  Fri Sep 15 00:17:40 2017    28    3  252199
# 252200  Fri Sep 15 00:17:30 2017     1    2  252200
# 252201  Fri Sep 15 00:08:38 2017     1    3  252201
# 252202  Fri Sep 15 00:12:55 2017    11    2  252202
# 252203  Fri Sep 15 00:12:19 2017     2    1  252203
# 252204  Fri Sep 15 00:12:02 2017     7    3  252204
# 252205  Fri Sep 15 00:10:40 2017     1    0  252205
# 252206  Fri Sep 15 00:09:59 2017     3    6  252206
# 252207  Fri Sep 15 00:09:03 2017     3    2  252207
# 252208  Fri Sep 15 00:14:42 2017     3    2  252208
# 252209  Fri Sep 15 00:13:24 2017     0    3  252209
# 252210  Fri Sep 15 00:12:56 2017     4    3  252210
# 252211  Fri Sep 15 00:03:11 2017     1    0  252211
# 252212  Fri Sep 15 00:06:40 2017     6    0  252212
# 252213  Fri Sep 15 00:06:00 2017     6    1  252213
# 252214  Fri Sep 15 00:05:58 2017     3    0  252214
# 252215  Fri Sep 15 00:04:56 2017     2    2  252215
# 252216  Fri Sep 15 00:04:39 2017    13    3  252216
# 252217  Fri Sep 15 00:04:21 2017     5    1  252217
# 252218  Fri Sep 15 00:04:14 2017     1    1  252218
# 252219  Fri Sep 15 00:04:08 2017     6    7  252219
# 252220  Fri Sep 15 00:04:05 2017     4    2  252220
# 252221  Fri Sep 15 00:03:42 2017     3    0  252221
# 252222  Fri Sep 15 00:08:23 2017     1    2  252222
# 252223  Fri Sep 15 00:06:51 2017     3    1  252223
# 252224  Fri Sep 15 00:06:47 2017     3    0  252224
# 252225  Fri Sep 15 00:02:30 2017     1    1  252225
# 252226  Fri Sep 15 00:02:04 2017     4    0  252226
# 252227  Fri Sep 15 00:01:46 2017     4    3  252227
# 252228  Fri Sep 15 00:00:03 2017     5    4  252228
#
# [252229 rows x 7 columns]

# %%
## load 'article_cutted'
with open("article_cutted", "rb") as file:
    sentences = pickle.load(file)

# %%
sentences[0:5]
# Out:
# [['韓瑜',
#   '協志',
#   '前妻',
#   '正',
#   '女演員',
#   '周子',
#   '瑜',
#   'TWICE',
#   '團裡裡面',
#   '台灣',
#   '人',
#   '正',
#   '兩個',
#   '要當',
#   '鄉民',
#   '老婆',
#   '選',
#   '五樓',
#   '真',
#   '勇氣'],
#  ['dear',
#   'all',
#   '逢甲',
#   '碟仙',
#   '發生',
#   '民國',
#   '七十五年',
#   '三月中',
#   '事情',
#   '一堆',
#   '大學生',
#   '玩',
#   '碟仙',
#   '後發',
#   'bbs',
#   '成功',
#   '預測',
#   '地震',
#   '小弟',
#   '預言',
#   '都還沒',
#   '出生',
#   '後面',
#   '說',
#   '預言',
#   '一百',
#   '一十六年',
#   '兩岸',
#   '統一',
#   '統一',
#   '對岸',
#   '對岸',
#   '統一',
#   '應該',
#   '不用',
#   '猜',
#   '真的',
#   '存在',
#   '預言',
#   '這種',
#   '事情',
#   '倒底',
#   '被統',
#   '知道',
#   '資料庫',
#   '發文',
#   '日期',
#   '輕鬆',
#   '改變',
#   '拍照',
#   '狀況',
#   '下',
#   '碟仙',
#   '真的假',
#   '有沒有',
#   '科學',
#   '經驗',
#   '法則',
#   '破解',
#   '謠言',
#   '真實',
#   '八卦'],
#  ['晚上',
#   '好',
#   '預備',
#   '唱',
#   '風雲',
#   '山河',
#   '動',
#   '國軍',
#   '早上',
#   '唱',
#   '有沒有',
#   '相關',
#   '八卦',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'Xiaomi',
#   'Redmi',
#   'Note'],
#  ['明天',
#   '早起',
#   '睡覺',
#   '旁邊',
#   'Youtube',
#   '眼睛',
#   '壞掉',
#   '有沒有',
#   '方法',
#   '早點',
#   '睡',
#   '掛',
#   'Sent',
#   'from',
#   'JPTT',
#   'on',
#   'my',
#   'HTC',
#   'D10i'],
#  ['一段時間',
#   '注意',
#   'LOL',
#   '發現',
#   '各大',
#   'LOL',
#   '討論區',
#   '人數',
#   '明顯',
#   '下降',
#   '趨勢',
#   '實在',
#   '令人',
#   '驚訝',
#   '曾經',
#   '一時',
#   '遊戲',
#   '霸主',
#   '漸漸',
#   '過氣',
#   'LOL',
#   '確實',
#   '撐',
#   '久',
#   '現在',
#   '算',
#   '厲害',
#   '遊戲',
#   '玩久',
#   '會膩']]

# %% [markdown]
# ## define y (push > boo)

# %%
## drop data
diff_threshold = 20
df = df[abs(df['push']-df['boo']) > diff_threshold].copy()

# %%
## define y
df['type'] = np.clip(df['push']-df['boo'], 0, 1)
df = df.reset_index(drop=True)

# %%
df['type'].value_counts()
# Out:
# 1    17318
# 0     1134
# Name: type, dtype: int64

# %% [markdown]
# ## simple feature

# %%
## word count
## http://blog.csdn.net/gatieme/article/details/43235791 (中文正則表達式)
df['word_count'] = df['content'].str.count('[a-zA-Z0-9]+') + df['content'].str.count('[\u4e00-\u9fff]')

# %%
## punctuation count
## 請產生 "標點符號數" 欄位

# %%
## question mark count
## 請產生 "問號數" 欄位

# %%
## 可以自由發揮想像還有什麼 features , etc. 比例

# %%
## drop punctuation column
df = df.drop(['punctuation'],axis=1)

# %%
df.iloc[:5, -4:]
# Out:
#    type  word_count  punctuation_count  question_count
# 0     1         175                  0               0
# 1     1         145                  4               1
# 2     1         393                 17               8
# 3     1         295                 15               6
# 4     1          41                  4               0

# %%
## compute correlation
## 請計算前面建立好的 features 與 type 的 correlation
# Out:
#                        type  word_count  punctuation_count  question_count
# type               1.000000   -0.045100          -0.024124       -0.056966
# word_count        -0.045100    1.000000           0.738419        0.534900
# punctuation_count -0.024124    0.738419           1.000000        0.342150
# question_count    -0.056966    0.534900           0.342150        1.000000

# %% [markdown]
# ## bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
## define transformer (轉換器)
vectorizer = CountVectorizer()
count = vectorizer.fit_transform([' '.join(x) for x in sentences])

# %%
count
# Out:
# <252229x372654 sparse matrix of type '<class 'numpy.int64'>'
# 	with 7700068 stored elements in Compressed Sparse Row format>

# %%
## save data as pickle format
with open("article_count", "wb") as file:
    pickle.dump([vectorizer, count], file)

# %% [markdown]
# ### select top 10 frequency of words

# %%
## 用前面轉換好的 count matrix, 嘗試抽出 top 10 count 最多的關鍵字
## 建立 top 10 count 關鍵字的 bag of words features, 計算其與 type 的 correlation

# %% [markdown]
# # TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
## define transformer (轉換器)
vectorizer = TfidfVectorizer(norm=None) ## do not do normalize
tfidf = vectorizer.fit_transform([' '.join(x) for x in sentences])

# %%
## save data as pickle format
with open("article_tfidf", "wb") as file:
    pickle.dump([vectorizer, tfidf], file)

# %% [markdown]
# ### select top 10 average tf-idf of words

# %%
## 用前面轉換好的 tfidf matrix, 嘗試抽出 top 10 平均 tfidf 最高的關鍵字
## 建立 top 10 平均 tfidf 關鍵字的 tf-idf features, 計算其與 type 的 correlation
